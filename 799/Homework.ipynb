# %% [markdown]
# # Homework Week 1
# ## Preparing datasets for analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# %%
# Out:
# Path to dataset files: C:\Users\santo\.cache\kagglehub\datasets\imranalishahh\marketing-and-product-performance-dataset\versions\1
