# %%
pip uninstall numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping numpy as it is not installed.

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.8 MB 6.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.8 MB 7.7 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.8 MB 8.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.8 MB 9.7 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 10.6 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.0 MB 18.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 19.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 18.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
# ...
